# %% [markdown]
# # Problems for Session 5

# %% [markdown]
# ### Table of Contents
#
# * [General concepts](#Background)
#
# * [Problem 1 - A model of savings behavior.](#Problem1)
#
# * [Problem 2 - A Monopolist Behaviour.](#Problem2)
#
# * [Problem 3 - A labour supply model.](#Problem3)
#
# * [Problem 4 - Taxation in the labour supply model.](#Problem4)

# %% [markdown]
# ### General concepts

# %% [markdown]
# ##### Theory: The Intertemporal Utility Function
#
# A plan for consumption in the periods $0, 1, ... , T-1$ is denoted ${c_t}^{T-1}_{t=0}$, where $c_t$ is the consumption in period $t$. We say the plan has time horizon T.
#
# Period 0 (‘the initial period’) need not refer to the ‘birth’ of the household but is just an arbitrary period within the lifetime of the household .
#
# We assume that preferences of a household or consumer can be represented by a time-separable intertemporal utility function with a constant utility discount rate and no utility from leisure (the latter assumption implies that the labour supply curve of the household in each period is inelastic, i.e., whatever the changes of prices of labour and leisure the supply of labour stays the same).
#
# The time-separability itself just means that the intertemporal utility funciton is additive.
#
# In addition, we assume geometric utility discounting, meaning that utility obtained $t$ periods ahead is converted into a present equivalent by multiplying by the discount factor $(1 + q)^{-t}$, where $q$
# is a constant utility discount rate.
# Hence, $$ u_t(c_t) = u(c_t)(1 + q)^{-t} $$ where $u(c)$ is a time-independent period utility function. Together, these two assumptions amount to:
# $$ U(c_0, c_1, ..., c_{T-1}) = u(c_0) + \frac{u(c_1)}{(1+q)} + ... +  \frac{u(c_{T -1})}{(1+q)^{T-1}} = \sum_{t = 0}^{T - 1} \frac{u(c_{t})}{(1+q)^{t}} $$
#
# The period utility function is assumed to satisfy $u'(c) > 0 $ and $u''(c) < 0 $.
#
# The number $ 1 + q$ tells how many units of utility in the next period the household insists on "in return" for a decrease of one unit of utility in the current period.
#
# So, a $q > 0$ will reflect that if the chosen level of consumption is the same in two periods, then the individual always appreciates a marginal unit of consumption higher than earlier it arrives.
#
# This explains why $q$ is named the rate of time preference or rate of impatience.
#
# The utility discount factor, $(\frac{1}{1+q})^t$, indicates how many units of utility the household is at most willing to give up in period 0 to get one additional unit of utility in period $t$.
#
# Now we assume that the consumer has a utility function over consumption today (time period 0, $t = 0$) and the future (time period 1, $t = 1$). Say,
# $$ u(c_{t = 0},c_{t = 1}) = c_{t = 0}^{\alpha} + \frac{1}{1+q} \times c_{t = 1}^{\alpha} $$
# where $\alpha$ is a parameter between 0 and 1, say 0.5, and $q$ is a given number for instance 0.04.
#
# The consumer has some income or endowment ($e$ or $I$)in both periods but can also save or borrow money. Savings $s$ is given by: $$ s = e_0 - c_{t = 0} $$
# and consumption in period 2 is given by: $$ c_{t = 1} = e_1 + s \times (1+r)$$
# where $r$ is the interest rate ($s$ will be negative if the consumer borrows money). Since $e_1$ is in tomorrow's money, we have to multiply the savings we bring forward by $(1 + r)$. Therefore, we can put this into our
# numerical framework by substituting for $s$, which gives us a budget constraint:
# $$ c_{t = 1} = e_1+ (e_0- c_{t = 0}) \times (1+r)$$
#
# Source: Groth, Lecture notes in macroeconomics, (mimeo) 2016

# %% [markdown]
# ##### Theory: The Firm - Monopoly
#
# ###### Fundamentals
#
# A monopoly consists of one firm that produces a unique product or service with no close substitutes. It has high barriers to entry, which gives the firm market power (i.e., the power to raise price above marginal cost).
# Some definitions,
#
# $$ AR = Demand_{market} = Price $$
#
# Marginal revenue: change in revenue resulting from a one-unit increase in output.
#
# * $MR > 0 \mbox{} \rightarrow$ Revenue increases
# * $MR < 0 \mbox{} \rightarrow$ Revenue decreases
#
# When the demand curve is downward sloping, the $ price = AR$ is above MR for all units sold at the same price.
# There is no supply curve in monopolistic markets. That is, there is a one-to-one relationship between price and the quantity produced
#
# ###### Profit Maximization for Monopolists
#
# All profit maximizing firms, regardless of the structure of the markets in which they sell, maximize profits by setting output such that marginal revenue equals marginal cost. $$ MR = MC $$
#
# Monopolists are ‘price makers’ in the sense that they can set their prices by picking a point on the demand curve. Note that they are not free of constraint; the demand curve dictates the maximum price they can charge for every quantity level.
#
# - The task for the profit-maximizing monopolist is to determine which point on the demand curve maximizes their profits.
#
# A downward sloping demand curve will mean that the firm faces a trade-off:
#
# - they can sell more but must lower their price to do so. This means that the marginal revenue of a monopolist will depend on their output decision.
#
# The total revenue for a firm is the amount of goods they sell, $Q$, multiplied by the price at which they sell the goods, $p$. Note that $Q$ is both the firm’s output and the market output as there is only the one firm supplying the market. $$ TR = p\times Q$$
#
# The firm’s marginal revenue is the change in total revenue from the sale of one more unit of their output. Thus a firm that earns $\Delta TR$ extra revenue from the sale of $\Delta Q$ more units has a marginal revenue of:
# $$MR = \frac{\partial TR}{\partial Q}$$
# Dividing both sides by ∆Q gives us an expression for marginal revenue:
# $$MR= p+Q\frac{\Delta p}{\Delta Q}$$
#
# Where:
# - The first part, $p$, is the extra revenue the firm gets from selling an extra unit of the good.
# - The second part, $Q\frac{\Delta p}{\Delta Q}$ , which is negative, is the decrease in revenue from the fact that increasing output marginally, lowers the price the firm receives for all of its output.
#
# Since the second part is negative we know that the MR curve is below the demand curve for every Q since demand curve relates price and quantity.
#
# A profit maximizing firm chooses output such that the marginal cost of producing that output exactly matches the marginal revenue it gets from selling that output.
#
# The intersection of the marginal revenue and marginal cost curves occurs at point $Q^M $ and the highest price at which the monopolist can sell exactly $Q^M $ is $p^M $. At $Q^M $ the total revenue is simply $(p^M ) \times (Q^M )$, and total cost is $(AC) \times (Q^M )$ since AC is just $\frac{TC}{Q}$.
#
# Suppose the demand for a good produced by a monopolist is $p = A - BQ$. Note that this is an inverse demand curve a demand curve written with price as a function of quantity. We can find the marginal revenue curve by first noting that $TR = p \times Q$. Thus:  $$TR = (A - BQ) \times Q$$ or $$TR = AQ - BQ^{2}$$
# In other words, for an inverse demand curve, $p = A - BQ$, the marginal revenue curve is $MR = A - 2BQ$.
#
# source: https://open.oregonstate.education/intermediatemicroeconomics/chapter/module-15/

# %% [markdown]
# ##### Theory: Labour Supply and Taxation

# %% [markdown]
# ##### Import Modules and Define solvers

# %%
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def our_newton_maximizer(funcname, startvalue, arglist):
    
    ''' Parameters: 
            funcname = Function to optimize
            startvalue = Value to start the research of optimal value 
            arglist = optimal values for the function
            
        Returns: 
            Optimal value for which the function is solved '''
    
    current = startvalue
    
    fval = funcname(current, arglist)
    
    #Approximation of the tangent line
    grad = (funcname(current+0.5*1e-5,arglist) - funcname(current-0.5*1e-5,arglist))*1e+5
    
    secgrad1 = (funcname(current+0.5*1e-5+0.5*1e-5,arglist) - funcname(current-0.5*1e-5+0.5*1e-5,arglist))*1e+5
    secgrad2 = (funcname(current+0.5*1e-5-0.5*1e-5,arglist) - funcname(current-0.5*1e-5-0.5*1e-5,arglist))*1e+5
    
    secderiv = (secgrad1 - secgrad2) * 1e+5
    
    while (abs(grad)>1e-8):
        
        #The algorithm 
        current = current - grad/secderiv
        
        fval = funcname(current, arglist)
        grad = (funcname(current+0.5*1e-5,arglist) - funcname(current-0.5*1e-5,arglist))*1e+5
        
        secgrad1 = (funcname(current+0.5*1e-5+0.5*1e-5,arglist) - funcname(current-0.5*1e-5+0.5*1e-5,arglist))*1e+5
        secgrad2 = (funcname(current+0.5*1e-5-0.5*1e-5,arglist) - funcname(current-0.5*1e-5-0.5*1e-5,arglist))*1e+5
        secderiv = (secgrad1-secgrad2) * 1e+5

    return current

# %%
def our_newton_solver(funcname, startvalue, arglist):
    
    ''' Parameters: 
            funcname = Function to optimize
            startvalue = Value to start the research of optimal value 
            arglist = optimal values for the function
            
        Returns: 
            Optimal value for which the function is solved '''
    
    current = startvalue
    fval = funcname(current, arglist)
    grad = (funcname(current+0.5*1e-5,arglist) - funcname(current-0.5*1e-5,arglist))*1e+5
    
    while (abs(fval)>1e-8):
        
        #The algorithm
        current = current - fval/grad
        fval = funcname(current,arglist)
        grad = (funcname(current+0.5*1e-5,arglist) - funcname(current-0.5*1e-5,arglist))*1e+5  
        
    return current

# %% [markdown]
# ### Problem 1 - A model of savings behavior (Fisher).<a class="anchor" id="Problem1"></a>
#
# This is a classical application of the consumer model.
#
# [[Back to TOC]](#Table-of-Contents)

# %% [markdown]
# ##### Problem 1a.
#
# Assume that the consumer has a utility function over consumption today (period 1) and the future (period 2). Choose $$ u(c_1,c_2) = {c_1}^e + \frac{1}{1+q} \times {c_2}^e $$ where e is a parameter between 0 and 1, say 0.5, and q is 0.04.
# The consumer has income in both periods, but can also save or borrow money. In particular, savings s is given by
# $ I_1 - c_1 $ and consumption in period 2 is given by $ I_2 + s(1+r) $, where r is the interest rate. Since s will be negative if the consumer borrows money, we can put this into our numerical framework by substituting for s, giving a budget constraint: $$ c_2 = I_2 + (I_1 - c_1) \times (1+r) $$
#
# Try to go through the same exercise as lecture 4 using this model, assessing the effects of a change in the interest rate r.

# %%
def f(rs):
    
    for element in range(len(rs)):
        r = rs[element]
       
        def utility(c1, c2):
            e = 0.5 #This tells us the curvature of the utility function. 
            q = 0.04
            return np.power(c1,e)+(1/(1+q))*np.power(c2,e)
        
        def utility_budget(c1, ip_list):
            I1 = ip_list[0]
            I2 = ip_list[1]
            r = ip_list[2]
            c2 = I2 + (I1 - c1)*(1+r) #Future Value formula
            return utility(c1, c2) 
         
        def demand(I1, I2, r):
            c1 = our_newton_maximizer(utility_budget, 0.1, [I1, I2, r])
            c2 = I2 + (I1 - c1) * (1+r)
            return c1, c2
        
        def indiff_dist(c2, mylist): 
            c1 = mylist[0]
            utility_level = mylist[1]
            utitility_achieved = utility(c1,c2)
            return utitility_achieved - utility_level

        def indifference(c1, util):
            return our_newton_solver(indiff_dist, 1, [c1,util])
        

        def indirect_utility(I1, I2, r):
            c11, c22 = demand(I1, I2, r)
            return utility(c11, c22)

        #Initialise quantiites of good 1 (x), income (I), and prices of the two goods
        c1 = np.linspace(1,30,100)
        I1 = 10
        I2 = 12

        #Get indirect utility curve here
        utility_level = indirect_utility(I1, I2, r)
        c2 = np.zeros(len(c1))

        for idx in range(len(c1)):
            c2[idx] = indifference(c1[idx], utility_level)


        #Compute the optimal demand for each r
        dem = []
        dem = demand(I1,I2,r)    

        # plot and make nice
        plt.figure(figsize = (6,4)) 
        
        plt.plot(c1, c2, label = f'Indifference curve with r = {np.round(r,2)}')
        plt.plot(c1, I2 + (I1 - c1)*(1+r), color = 'red', label = 'budget line')
        
        plt.scatter(dem[0], dem[1], label = "Optimum demand", color ='black')
        plt.text(dem[0], dem[1], '({}, {})'.format(np.round(dem[0],2), np.round(dem[1],2)))
        
        plt.xlabel('Quantity of goods consumed today') 
        plt.ylabel('Quantity of goods consumed tomorow')
        
        plt.legend(loc = 'upper right')
        plt.title('Evolution of indifference curves when interest rates varies')
        
        plt.xlim(0,30)
        plt.ylim(0,30)
        plt.show()

# %%
#Since e is between 0 and 1
rs = np.arange(0.1,0.9,0.1)

f(rs)

# %% [markdown]
# ##### Problem 1b.
# Show that if the interest rate is 0.04, the consumer wants to consume as much in period 1 as in period 2.

# %% [markdown]
# - From the graph above when r = 0.4, the consumer consume more tomorrow (period 2) than in (period 1).

# %% [markdown]
# ##### Problem 1c.
# Using the assumption in point b as a starting point, check how the income effects of an increase in the interest rate depends on whether the consumer initially borrows or saves money, which would then depend on $I_1$ and $I_2$.

# %% [markdown]
# ###### Case A: Saver

# %%
def utility(c1, c2):
    e = 0.5
    q = 0.04
    return np.power(c1,e)+(1/(1+q))*np.power(c2,e)

def utility_budget(c1, ip_list):
    I1 = ip_list[0] 
    I2 = ip_list[1] 
    r = ip_list[2]
    c2 = I2 + (I1 - c1)*(1+r)
    return utility(c1, c2)
    
def demand(I1, I2, r):
    c1 = our_newton_maximizer(utility_budget, 0.1, [I1, I2, r])
    c2 = I2 + (I1 - c1)*(1+r)
    return c1, c2

def indiff_dist(c2, mylist): 
    c1 = mylist[0] 
    utility_level = mylist[1]
    utitility_achieved = utility(c1,c2)
    return utitility_achieved - utility_level

def indifference(c1, util):
    return our_newton_solver(indiff_dist, 1, [c1,util])

def indirect_utility(I1, I2, r):
    c11, c22 = demand(I1, I2, r)
    return utility(c11, c22)

def diff_indirect_utilities(income_to_be_found,longlist):
    I1 = longlist[0]
    I2 = longlist[1]
    r1 = longlist[2] 
    r2 = longlist[3]
    return indirect_utility(I1, I2, r1) - indirect_utility(I1,income_to_be_found,r2)

# define the parameters
I1 = 12 
I2 = 8 
r1 = 0.1 
r2 = 0.85


# Give optimal income level for period 2 when prices change
a = our_newton_solver(diff_indirect_utilities, 1, [I1, I2, r1, r2])

# quantity of good today
c1 = np.linspace(0.1, 10, 100) 

# plot with the new budget line as well
plt.figure(figsize = (12, 8))

#Budget Curve 1: Before changes
plt.plot(c1, I2 + (I1 - c1)*(1+r1), color = 'pink', label = 'budget curve 1')

#Budget Curve 2: After changes
plt.plot(c1, a + (I1 - c1)*(1+r2), color = 'red', label = 'budget curve with a')

#Get the utility levels
u_bar = indirect_utility(I1, I2, r1) 
u_bar2 = indirect_utility(I1, I2, r2)


#Express utility max as a function of quantity of good tomorrow
c21 = np.zeros((100,1)) 
c22 = np.zeros((100,1))


for idx in range(len(c1)):
    c21[idx] = indifference(c1[idx], u_bar)
    c22[idx] = indifference(c1[idx], u_bar2)

plt.plot(c1, c21, label = 'indifference curve 1', color = 'green') 
plt.plot(c1, c22, label = 'indifference curve 2', color = 'blue')

#Find utility-maximising consumption bundle
dems1 = demand(I1, I2, r1) 
plt.scatter(dems1[0], dems1[1],s=50,alpha=0.5,color='black')

dems2 = demand(I1, I2, r2) 
plt.scatter(dems2[0], dems2[1],s=50,alpha=0.5,color='black')


plt.annotate('A', xy = (dems1[0], dems1[1]), xycoords='data',rotation = 30, size=15)
plt.annotate('B', xy = (dems2[0], dems2[1]), xycoords='data',rotation = 30, size=15)

plt.vlines(dems1[0],0,dems1[1],linestyles='dotted')
plt.vlines(dems2[0],0,dems2[1],linestyles='dotted')

plt.hlines(dems1[1],0,dems1[0], linestyles='dotted')
plt.hlines(dems2[1],0,dems2[0], linestyles='dotted')

plt.ylim(0,40) ; plt.xlim(0,10)
plt.title('Income and Substitution effect: Consequences on consumption in time')
plt.xlabel('consumption today, c1') 
plt.ylabel('consumption tomorrow, c2')
plt.legend(loc = 'upper right')

# %%
s = I1 - dems1[0]
print(f'Remaining Income given the demand: {s}')
# Out:
# Remaining Income given the demand: 2.444911153110837

# %% [markdown]
# Therefore, our consumer have a higher income in the first period than in the second period as a result of a higher interest rate in the second period (0.85) in comparison to the first period (0.1). This result for our consumer to save at the present time since its remaining income is positive as seen above.

# %% [markdown]
# ###### Case B: Borrower

# %%
def utility(c1, c2):
    e = 0.5
    q = 0.04
    return np.power(c1,e)+(1/(1+q))*np.power(c2,e)

def utility_budget(c1, ip_list):
    I1 = ip_list[0] 
    I2 = ip_list[1] 
    r = ip_list[2]
    c2 = I2 + (I1 - c1)*(1+r)
    return utility(c1, c2)
    
def demand(I1, I2, r):
    c1 = our_newton_maximizer(utility_budget, 0.1, [I1, I2, r])
    c2 = I2 + (I1 - c1)*(1+r)
    return c1, c2

def indiff_dist(c2, mylist): 
    c1 = mylist[0] 
    utility_level = mylist[1]
    utitility_achieved = utility(c1,c2)
    return utitility_achieved - utility_level

def indifference(c1, util):
    return our_newton_solver(indiff_dist, 1, [c1,util])

def indirect_utility(I1, I2, r):
    c11, c22 = demand(I1, I2, r)
    return utility(c11, c22)

def diff_indirect_utilities(income_to_be_found,longlist):
    I1 = longlist[0] 
    I2 = longlist[1]
    r1 = longlist[2] 
    r2 = longlist[3]
    return indirect_utility(I1, I2, r1) - indirect_utility(I1,income_to_be_found,r2)

#Define the parameters
I1 = 2 
I2 = 10 
r1 = 0.9
r2 = 0.05

'''So this should find the income level that would together with prices 1 and 1 (the last two arguments)
 would give the same utility as an income level of 10, together with prices 2 and 1'''

a = our_newton_solver(diff_indirect_utilities, 1, [I1, I2, r1, r2])

# quantity of good 1
c1 = np.linspace(0.1, 10, 100) 

# plot with the new budget line as well
plt.figure(figsize = (12, 8))

# Budget curve: price1 = 2, income = 10
plt.plot(c1, I2 + (I1 - c1)*(1+r1), color = 'pink', label = 'budget curve 1')

# Budget curve: price1 = 1, income = a (gives the same utility as income of 10)
plt.plot(c1, a + (I1 - c1)*(1+r2), color = 'red', label = 'budget curve with a')

# Get the utility levels
u_bar = indirect_utility(I1, I2, r1) 
u_bar2 = indirect_utility(I1, I2, r2)

# Express utility max as a function of quantity of good 2
c21 = np.zeros((100,1)) ; c22 = np.zeros((100,1))

for idx in range(len(c1)):
    c21[idx] = indifference(c1[idx], u_bar)
    c22[idx] = indifference(c1[idx], u_bar2)

plt.plot(c1, c21, label = 'indifference curve 1', color = 'green') 
plt.plot(c1, c22, label = 'indifference curve 2', color = 'blue')

#Find utility-maximising consumption bundle
dems1 = demand(I1, I2, r1) ; plt.scatter(dems1[0], dems1[1],s=50,alpha=0.5,color='black')
dems2 = demand(I1, I2, r2) ; plt.scatter(dems2[0], dems2[1],s=50,alpha=0.5,color='black')


plt.annotate('A', xy = (dems1[0], dems1[1]), xycoords='data',rotation = 30, size=15)
plt.annotate('B', xy = (dems2[0], dems2[1]), xycoords='data',rotation = 30, size=15)

plt.vlines(dems1[0],0,dems1[1],linestyles='dotted')
plt.vlines(dems2[0],0,dems2[1],linestyles='dotted')
plt.hlines(dems1[1],0,dems1[0], linestyles='dotted')
plt.hlines(dems2[1],0,dems2[0], linestyles='dotted')
plt.ylim(0,40) ; plt.xlim(0,10)
plt.title('Income and Substitution effect: Consequences on consumption in time')
plt.xlabel('Consumption goods today, c1') ; plt.ylabel('Consumption goods tomorrow, c2')
plt.legend(loc = 'upper right')

# %%
s = I1 - dems1[0]
print(f'Remaining Income given demand: {s}')
# Out:
# Remaining Income given demand: -0.63477045211551

# %% [markdown]
# Therefore, in this case since the interest is smaller in the second period (0.05) in comparison to the first period (0.9) our consumer prefers to boroower today (as seen above) and spend more that it earns because of the expected low levels of interest rate in the next period.

# %% [markdown]
# ##### Problem 1d.
# Set up a model with 100 such consumers. Let all of them have second period income equal to 1, but let first period incomes be distributed uniformly on the interval from 0 to 2. Plot the change in period 1 consumption (as a proxy for welfare) before and after an interest rate increase against period 1 income.

# %%
#Do for i in I1 = I1[i] 
def utility(c1, c2):
    e = 0.5 
    q = 0.04
    return np.power(c1,e)+(1/(1+q))*np.power(c2,e)

def utility_budget(c1, ip_list):
    I1 = ip_list[0] ; I2 = ip_list[1] ; r = ip_list[2]
    c2 = I2 + (I1 - c1)*(1+r)
    return utility(c1, c2)
    
def demand(I1, I2, r):
    c1 = our_newton_maximizer(utility_budget, 0.1, [I1, I2, r])
    c2 = I2 + (I1 - c1)*(1+r)
    return c1, c2

def indiff_dist(c2, mylist): 
    c1 = mylist[0] 
    utility_level = mylist[1]
    utitility_achieved = utility(c1,c2)
    return utitility_achieved - utility_level

def indifference(c1, util):
    return our_newton_solver(indiff_dist, 1, [c1,util])

def indirect_utility(I1, I2, r):
    c11, c22 = demand(I1, I2, r)
    return utility(c11, c22)

def diff_indirect_utilities(income_to_be_found,longlist):
    I1 = longlist[0] 
    I2 = longlist[1] 
    r1 = longlist[2] 
    r2 = longlist[3]
    return indirect_utility(I1, I2, r1) - indirect_utility(I1,income_to_be_found,r2)

#Define the parameters
n = 100 

In1 = np.random.uniform(0,2,n) 
I2 = 8 

r1 = 0.4 
r2 = 0.5

before = []
after = [] 

for i in range(n):
    I1 = In1[i]

    demo1, demo2 = demand(I1,I2,r1)
    before.append(demo1)

    demo1, demo2 = demand(I1,I2,r2)
    after.append(demo1)

c1 = np.linspace(1,100,100)   
plt.plot(c1,before, label = "Before")
plt.plot(c1,after, label = "After")
plt.xlabel("Customers") 
plt.ylabel("Quantity consumed today")
plt.legend()

# %%
#Define the things we need
n = 100 

In1 = np.random.uniform(0,2,n) 
I2 = 1 

r1 = 0.9 
r2 = 0.05

before = [] 
after = []

for i in range(n):
    I1 = In1[i]
    #Income level
    a = our_newton_solver(diff_indirect_utilities, 1, [I1, I2, r1, r2]) 
    #Quantity of good today
    c1 = np.linspace(0.1, 10, 100) 


    #Get the utility levels
    u_bar = indirect_utility(I1, I2, r1) 
    u_bar2 = indirect_utility(I1, I2, r2)

    #Express utility max as a function of quantity of good 2
    c21 = np.zeros((100,1)) 
    c22 = np.zeros((100,1))

    for idx in range(len(c1)):
        c21[idx] = indifference(c1[idx], u_bar)
        c22[idx] = indifference(c1[idx], u_bar2)
        
    before.append(c21[idx]) 
    after.append(c22[idx])

plt.plot(c1, before)
plt.plot(c1, after)
# Out:
# /var/folders/yf/6hqzqjrx1cq648tm_nv4ljqw0000gn/T/ipykernel_1150/1783774506.py:5: RuntimeWarning: invalid value encountered in power
#   return np.power(c1,e)+(1/(1+q))*np.power(c2,e)

# %% [markdown]
# Since in the preceding period, the interest rate is not high, people do not have any incentive to save money for period 2. Therefore, they consume more in period 1.

# %% [markdown]
# ### Problem 2 - A monopolist Behaviour.<a class="anchor" id="Problem2"></a>
# [[Back to TOC]](#Table-of-Contents)

# %%
def shotgun_maximizer(funcname,startvalue,arglist):
    
    ''' startvalue will here be a list of three numbers  '''
    
    xs = np.linspace(startvalue[0], startvalue[1], startvalue[2])
    ys = funcname(xs, arglist)
    ind = np.argmax(ys) 
    
    ''' Return the indice where the maximum value of the function is found '''
    
    return xs[ind]

def shotgun_maximizer2(funcname, startvalue, arglist):
    
    ''' startvalue will here be a list of three numbers '''
    
    xs = np.linspace(startvalue[0], startvalue[1], startvalue[2])
    ys = np.zeros_like(xs)
    
    for i in range(startvalue[2]):
        ys[i]= funcname(xs[i], arglist)
        
    ind = np.argmax(ys)
    
    return xs[ind]

def BigK(labor, capital):
    return labor**0.6*capital**0.4

def profit(labor, mylist):
    
    p = mylist[0]
    w = mylist[1]
    C = mylist[2]
    fval = p*BigK(labor,10) - w*labor - C
    
    return fval

def supply(mylist, starting_value):
    
    labor = shotgun_maximizer(profit, [0.1,100,1000], mylist)
    labor = our_newton_maximizer(profit, labor,mylist)
    
    return BigK(labor,10), labor

def f_inv(output):
    return output**(5/3)*10**(-2/3)

def profit2(output, mylist):
    
    p = mylist[0]
    w = mylist[1]
    C = mylist[2]
    
    return p*output-w*f_inv(output) - C

def supply2(mylist, starting_value):
    
    output = shotgun_maximizer(profit2, [0.1,100,1000], mylist)
    output = our_newton_maximizer(profit2, output, mylist)
    labor = f_inv(output)
    
    return output, labor    

def profit_monopolist(output, mylist):
    
    p = 10*output**(-0.5)
    w = mylist[0]
    C = mylist[1]
    
    return p*output-w*f_inv(output) - C

def supply_monopolist(mylist, starting_value):
    
    output = shotgun_maximizer(profit_monopolist, [0.1,100,100], mylist)
    output = our_newton_maximizer(profit_monopolist, output, mylist)
    labor = f_inv(output)
    price = 10*output**(-0.5)
    
    return output, labor, price

# %% [markdown]
# ##### Problem 2a.
# We will study a monopolist’s behavior under linear demand. Let the production technology be as in Session 5 and Let demand be given by $$ x = 10 - 2p $$ Figure out the monopolist’s price setting.

# %%
# Production Technology is defined under BigK, we need a fixed value for capital 
FCK = 10 
w = 1
prices = np.linspace(1,5,100)
quantities = np.zeros(100)
startv = 1

for i in range(100):
    quantities[i], startv = supply([prices[i], w, FCK], startv)

#Return the output, labour, prices and profit for the monopoly
mo, ml, mp = supply_monopolist([1,0],0.0001)
mpi = profit_monopolist(20,[6,5,1])

p = lambda q: 10*np.power(q,-0.5)

#Create Figure
plt.figure(figsize = (10, 6))

#Plot the curves
plt.plot(quantities, prices, "-k", label = "Marginal cost") 
plt.plot(quantities, p(quantities), "-r", label="Market demand")
plt.plot(quantities, p(quantities)+quantities*10*(-0.5)*quantities**(-1.5), "--g", label="Marginal Revenue")

#Plot the Monopolist equilibrium and price
plt.vlines(mo, 0, 10*np.power(mo,-0.5), linestyles='dotted')
plt.hlines(10*np.power(mo,-0.5), 0, mo, linestyles='dotted')
plt.scatter(mo, p(mo), label = "Monopolist price")

#Compute and Plot the Market equilibirum 
#Find the idex when the derivative is equal to zero (np.sign gives zero if difference is close to zero
idx = np.argwhere(np.diff(np.sign(prices - p(quantities)))).flatten() 

plt.vlines(quantities[idx], 0, p(quantities[idx]), linestyles='dotted')
plt.hlines(p(quantities[idx]), 0, quantities[idx], linestyles='dotted')
plt.scatter(quantities[idx], p(quantities[idx]), label = "Market Equilibrium")

#Graph Parameters
plt.legend(loc = "upper right")
plt.xlim(0, 30) 
plt.ylim(0, 5) 
plt.ylabel("Prices")
plt.xlabel("Quantities")
plt.title("Monopolist pricing compared with competetive pricing")
# Out:
# Text(0.5, 1.0, 'Monopolist pricing compared with competetive pricing')

# %% [markdown]
# ##### Problem 2b.
# Study a market with ten pricetaking firms, each with the same technology as in Session 5. The firms have capital stocks 1,2,3,4,5,6,7,8,9 and 10. Figure out the market supply curve, find the market equilibrium if the demand is given as in Problem 3a, and plot the production versus the capital stocks.

# %%
KS = np.arange(1,10,1) # The number of capital available

for i in range(len(KS)):
    
    capital = KS[i]
    
    def BigK(labor, capital):
        
        alpha = 0.6
        
        return np.power(labor,alpha)*np.power(capital,1-alpha)

    def profit(labor, mylist):
        
        p = mylist[0]
        w = mylist[1]
        FCK = mylist[2]
        fval = p*BigK(labor,capital)-w*labor - FCK
        
        return fval

    def supply(mylist, starting_value):
        
        labor = shotgun_maximizer(profit, [0.1,100,1000], mylist)
        labor = our_newton_maximizer(profit, labor, mylist)
        
        return BigK(labor,capital), labor

    def f_inv(output):
        return output**(5/3)*capital**(-2/3)

    def profit2(output, mylist):
        
        p = mylist[0] 
        w = mylist[1] 
        FCK = mylist[2]
        
        return p*output-w*f_inv(output) - FCK

    def supply2(mylist,starting_value):
        
        output = shotgun_maximizer(profit2, [0.1,100,1000], mylist)
        output = our_newton_maximizer(profit2, output, mylist)
        labor = f_inv(output)
        
        return output, labor    

    def profit_monopolist(output, mylist):
        
        p = 10*output**(-0.5) 
        w = mylist[1] 
        FCK = mylist[2]
        
        return p*output-w*f_inv(output) - FCK

    def supply_monopolist(mylist, starting_value):
        
        output = shotgun_maximizer(profit_monopolist, [0.1,100,100], mylist)
        output = our_newton_maximizer(profit_monopolist, output, mylist)
        labor = f_inv(output)
        price = 10*output**(-0.5)
        return output, labor, price

    # Production Technology is defined under BigK, we need a fixed value for capital 
    FCK = 10 
    w = 1 
    prices = np.linspace(1,5,100) 
    quantities = np.zeros(100) 
    startv=1
    
    for i in range(100):
        quantities[i], startv = supply([prices[i],w,capital], startv)

    #Return the output, labour, prices and profit for the monopoly
    outputs = np.linspace(1, 10, 100) 
    p = 6 
    w = 5 
    FC = 1
    mo, ml, mp = supply_monopolist([p,FC,capital], 1)

    p = lambda q: capital*np.power(q,-0.5)

    #Create Figure
    plt.figure(figsize = (8, 6))

    #Plot the curves
    plt.plot(quantities, prices, "-k", label = "Marginal cost") 
    plt.plot(quantities, p(quantities), "-r", label = "Market demand")
    plt.plot(quantities, 10*quantities**(-0.5) + quantities*10*(-0.5)*quantities**(-1.5), "--g", label = "Marginal Revenue")

    #Plot the Monopolist equilibrium and price
    plt.vlines(mo, 0, p(mo), linestyles = 'dotted')
    plt.hlines(p(mo),0,mo, linestyles = 'dotted')
    plt.scatter(mo,p(mo), label = "Monopolist price")

    #Compute and Plot the Market equilibirum 
    #Find the idex when the derivative is equal to zero (np.sign gives zero if difference is close to zero)
    idx = np.argwhere(np.diff(np.sign(prices - p(quantities)))).flatten() 
    plt.vlines(quantities[idx], 0, p(quantities[idx]), linestyles = 'dotted')
    plt.hlines(p(quantities[idx]), 0, quantities[idx], linestyles = 'dotted')
    plt.scatter(quantities[idx], p(quantities[idx]), label = "Market Equilibrium")

    #Graph Parameters
    plt.legend(loc = "upper right")
    plt.ylabel("Prices")
    plt.xlabel("Quantities")
    plt.title(f"Monopolist pricing compared with competetive pricing, for capital = {capital}")

# %% [markdown]
# ##### Problem 2c.
#
# [Hard] A monopsonist. Think about a firm that sells its goods on the world market (and can not affect the price) but has production facilities that are large relative to the place where it is located. Assume that the firm faces an increasing supply curve of labor. For simplicity, let: $$ l,\text labor= 1 + 0.1w $$
# Using the same techniques as in session 5, figure out the monopsonist’s choice of produced quantities.

# %%
ws = np.linspace(1, 15, 100) # The number of capital available
q_stars = [] 
FCK = 10

for i in range(len(ws)):
    w = ws[i]
    labor = 1 + 0.1*w
    
    def BigK(labor, capital):
        alpha = 0.6
        return np.power(labor,alpha)*np.power(capital,1-alpha)

    def profit(labor, mylist):
        
        p = mylist[0] 
        FCK = mylist[2] 
        fval = p*BigK(labor,capital)-w*labor - FCK
        
        return fval

    def supply(mylist, starting_value):
        
        labor = shotgun_maximizer(profit,[0.1,100,1000],mylist)
        labor = our_newton_maximizer(profit, labor, mylist)
        
        return BigK(labor,capital), labor

    def f_inv(output):
        return output**(5/3)*capital**(-2/3)
    

    def profit_monopolist(output, mylist):
        p = 10*output**(-0.5) 
        w = mylist[1] 
        FCK = mylist[2]
        return p*output-w*f_inv(output) - FCK

    def supply_monopolist(mylist,starting_value):
        output = shotgun_maximizer(profit_monopolist, [0.1,100,100], mylist)
        output = our_newton_maximizer(profit_monopolist, output, mylist)
        labor = f_inv(output)
        price = 10*output**(-0.5)
        
        return output, labor, price

    outp = np.linspace(1,15,100) ; p = 6 ; FCK = 1
    q_star = supply_monopolist([p,w,FCK],1)[0]

    q_stars.append(q_star)

plt.figure(figsize = (10,5))
plt.plot(ws, q_stars, label = 'production level chosen: wages vs quantity')
plt.legend() 
plt.title("monopsonist: chosen production production levels for varying labour and price")
plt.xlabel('wage cost') 
plt.ylabel('quantity chosen') 
plt.show()

# %% [markdown]
# ### Problem 3 - A labour supply model.<a class="anchor" id="Problem3"></a>
#
# This is another classical application of the consumer model, which we will use a lot in the following. The consumer chooses how much to work and how much to consume, that is, he/she trades off consumption versus leisure time.
#
# [[Back to TOC]](#Table-of-Contents)

# %% [markdown]
# ##### Problem 3a.
# The consumer has preferences over consumption $c$ and leisure $l$, which is really $1 - m$, where m is work. Let the utility be a type of quasi-linear utility:
# $$ u(c,m) = c - \frac{1}{\frac{1+1}{e}} \times m^\frac{1+1}{e} $$ The consumption has a price 1, and the wage $w$ is
# thus a real wage. The consumer has an income given by $ I + wm$, where $I$ is income that is independent of working, so $$ c = I + wm $$ is the budget. Where
#
# * $m$ shows how much our consumer work.
#
# Recall: the quasi-linear effect doesn't show any income effect or there is no income effect.

# %% [markdown]
# ##### Problem 3b.
# Go through the works from lecture 4:
# - Producing a labor supply curve for the consumer (how does labor supply depend on real wage)
# - Show how the income effect operates in the model, and
# - Find the labor supply elasticity (what happens to the relative change in labor supply when the real wage increases by 1%.)

# %%
#Producing a labor supply curve for the consumer (how does labor supply depend on real wage)
def part1(wages, arglist):
    
    I = arglist[0] 
    e = arglist[1] 
    
    for i in range(len(wages)): 
        
        w = wages[i]
        
        def utility(l, c, e):
            
            denominator = (1+1/(-e))
            
            return c + (1/denominator) * np.power(l, denominator)
            

        def utilitybudget(l, mylist):
            
            I = mylist[0] 
            e = mylist[2] 
            w = mylist[1] 
            c = I + w*(1 - l)
            
            return utility(l, c, e)

        def demand(I, w, e):
            
            l = our_newton_maximizer(utilitybudget, 0.1, [I, w, e])
            c = I + w * (1-l)
            
            return l, c

        def indiffdist(c, mylist):
            
            l = mylist[0] 
            utilitylevel = mylist[1] 
            e = mylist[2]
            utilityachieved = utility(l, c, e)
            
            return utilityachieved - utilitylevel  

        def indiff(l, util, e):    
            return our_newton_solver(indiffdist, 1, [l,util,e])

        def indirectutility(I, w, e) :
            
            l, c = demand(I, w, e) 
            return utility(l, c, e)

        # initiliase some quantities of the two goods
        l = np.linspace(0.1, 10, 100) 
        c = np.zeros(np.size(l)) 

        # get indirect utility curve here
        utility_level = indirectutility(I, w, e)
        c = np.zeros(len(l)) 
        dems = np.zeros(len(l))

        for element in range(len(l)):
            c[element] = indiff(l[element], utility_level, e)

        cons = lambda l,I,w: I + w*(1-l)

        plt.figure(figsize = (10,6))
        
        # plot and make nice
        plt.figure(figsize = (6,4)) 
        plt.plot(l, c, label = f'Indifference curve, w = {np.round(w,2)}')
        plt.plot(l,  cons(l,I,w), color = 'red', label = f'budget line, w = {np.round(w,2)}')

        # points
        dem = []
        dem= demand(I,w,e) 
        plt.scatter(dem[0],dem[1], label = "Optimum consumption and leisure", color ='black')
        plt.text(dem[0], dem[1], '({}, {})'.format(np.round(dem[0],2), np.round(dem[1],2)))
        plt.vlines(dem[0],0,dem[1],linestyles='dotted')
        plt.hlines(dem[1],0,dem[0],linestyles='dotted')

        plt.xlabel('Quantity of leisure, l') 
        plt.ylabel('Quantity of consumption, c')
        plt.legend(loc = 'lower left')
        plt.xlim(0,10) ; plt.ylim(0,18)
        plt.title('Quasi-linear utility, Work Supply problem')

# %%
ws = np.arange(1, 10, 1)

part1(ws, [10,0.5])

# %%
#Show how the income effect operates in the model
l = np.linspace(0.1, 10, 100) # quantity of good 1

def effect(l, arglist):
    I = arglist[0] 
    w1 = arglist[1] 
    w2 = arglist[2] 
    e1 = arglist[3] 
    e2 = arglist[4] 

    def utility(l,c,e):
        
        denominator = (1+1/(-e))
        return c + (1/denominator) * np.power(l, denominator)

    def utilitybudget(l, mylist):
        
        I = mylist[0] 
        e = mylist[2] 
        w = mylist[1] 
        c = I + w*(1 - l)
        
        return utility(l, c, e)

    def demand(I, w, e):
        
        l = our_newton_maximizer(utilitybudget, 0.1, [I,w,e])
        c = I + w*(1-l)
        
        return l, c

    def indiffdist(c, mylist):
        
        l = mylist[0] 
        utilitylevel = mylist[1] 
        e = mylist[2]
        utilityachieved = utility(l,c,e)
        
        return utilityachieved - utilitylevel  

    def indiff(l,util,e):    
        return our_newton_solver(indiffdist,1,[l,util,e])

    def indirectutility(I,w,e):
        
        l,c = demand(I,w,e) 
        return utility(l,c,e)

    def difference_in_indirect_utilities(income_to_be_found, longlist):
        
        I1 = longlist[0]
        w1 = longlist[1] 
        w2 = longlist[3] 
        e1 = longlist[2]
        e2 = longlist[4]
        
        return indirectutility(I1, w1, e1) - indirectutility(income_to_be_found, w2, e2)

    a = our_newton_solver(difference_in_indirect_utilities, 1, [I, w1, e1, w2, e2])
   

    # plot with the new budget line as well
    

    cons = lambda l,I,w: I + w*(1-l)

    # budget curve: price1 = 2, income = 10
    plt.plot(l, cons(l,I,w1), color = 'pink', label = 'budget curve 1')

    # budget curve: price1 = 1, income = a (gives the same utility as income of 10)
    plt.plot(l, cons(l,a,w2), color = 'red', label = 'budget curve with a')

    # budget curve: price1 = 1, income = 10
    plt.plot(l, cons(l,10,w2), color = 'purple', label = 'budget curve 2')

    # get the utility levels
    u_bar = indirectutility(I, w1, e1) 
    u_bar2 = indirectutility(I, w2, e2)

    # express utility max as a function of quantity of good 2
    y1 = np.zeros(len(l)) ; y2 = np.zeros(len(l))

    for idx in range(len(l)):
        y1[idx] = indiff(l[idx], u_bar,e1)
        y2[idx] = indiff(l[idx], u_bar2,e2)

    plt.plot(l, y1, label = 'indifference curve 1', color = 'green') 
    plt.plot(l, y2, label = 'indifference curve 2', color = 'lime')

    # find utility-maximising consumption bundle
    dems1 = demand(I, w1, e1) 
    plt.scatter(dems1[0], dems1[1],s=50,alpha=0.5,color='black')
    
    dems2 = demand(I, w2, e2) 
    plt.scatter(dems2[0], dems2[1],s=50,alpha=0.5,color='black')
    
    dems3 = demand(a, w2, e2) 
    plt.scatter(dems3[0], dems3[1],s=50,alpha=0.5,color='black')
    print(f"Optimum combination for the different incomes and prices : {dems1}, {dems1}, {dems3}")
    
    # make nice
    
    plt.vlines(dems1[0], 0, dems1[1], linestyles = 'dotted', color = 'k')
    plt.vlines(dems2[0], 0, dems2[1], linestyles = 'dotted', color = 'k')
    plt.vlines(dems3[0], 0, dems3[1], linestyles = 'dotted', color = 'k')
    
    plt.annotate('A', xy = (dems1[0], dems1[1]), xycoords='data', rotation = 30, size=15)
    plt.annotate('B', xy = (dems2[0], dems2[1]), xycoords='data', rotation = 30, size=15)
    plt.annotate('C', xy = (dems3[0], dems3[1]), xycoords='data', rotation = 30, size=15)

    plt.title('income and substitution effect quasi-linear utility')
    plt.xlabel('quantity, good 1') 
    plt.ylabel('quantity, good 2')
    plt.legend(loc = 'upper right', framealpha = 1) 
    plt.ylim(0, 20)
    plt.xlim(0,5) 
    plt.show()

# %%
effect(l,[10,1,3,0.1,0.8])
# Out:
# Optimum combination for the different incomes and prices : (0.9999999996817724, 10.000000000318227), (0.9999999996817724, 10.000000000318227), (0.4152436465970102, 14.87181264548168)

# %%
#Find the labor supply elasticity (what happens to the relative change in labor supply when the real wage increases by 1%.)
def utility(l,c,e):
    
    denominator = (1+1/(-e))
    return c + (1/denominator) * np.power(l, denominator)

def utilitybudget(l, mylist):
    
    I = mylist[0] 
    e = mylist[2] 
    w = mylist[1] 
    c = I + w*(1 - l)
    
    return utility(l, c, e)

def demand(I,w,e):
    
    l = our_newton_maximizer(utilitybudget, 0.1, [I,w,e])
    c = I + w*(1-l)
    
    return l, c

wages = np.linspace(1,11,100) 
work = []
elas = []

for idx in range(len(wages)):
    w = wages[idx] 
    
    #find leisure and append work 
    I = 10 
    e = 0.5   
    leisure = demand(I,w,e)[0]
    work.append(1 - leisure)  
    elas.append(np.log(leisure) / np.log(1-leisure))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,6))
ax1.plot(wages, work)
ax2.plot(wages,elas)

ax1.set_xlim([0,10]) 
ax1.set_ylim([0,0.7])
ax2.set_xlim([0,10]) 
ax2.set_ylim([0,3.5])

ax1.set_xlabel('Wages') 
ax2.set_xlabel('Wages')
ax1.set_ylabel('Work supply') 
ax2.set_ylabel('Work supply')
# Out:
# Text(0, 0.5, 'Work supply')

# %% [markdown]
# ##### Problem 3c.
# Assume that there are fixed costs of working. That is, the worker will have to pay a fixed cost $B$ if $ m > 0$. We can now solve the model by finding the consumer choice as before, but then comparing with the utility in $ m = 0$. If the utility is higher in $ m = 0 $, then the consumer chooses not to work.
#
# Note that B is a fixed amount that you received if you're not working.

# %%
from scipy import stats

# %%
def demandB(income, wage, e,B):
    
    def utility(l, c, e):
        denominator = (1+1/(-e))
        return c + (1/denominator) * np.power(l,denominator)
        

    def utilitybudget(l, mylist):
        
        I = mylist[0] 
        e = mylist[2] 
        w = mylist[1] 
        c = I + w*(1 - l)
        return utility(l, c, e)
    
    def demand(I,w,e):
        l = our_newton_solver(utilitybudget,0.1,[I,w,e])
        c = I + w*(1-l)
        return l, c

    #leisure, conumption = demand

    c, m = demand(income,wage,e)
    util = utility(c,m,e)-B
    util2 = utility(income,0,e)
    
    if util2 > util:
        c = income
        m = 0
        
    return c, m

Bs = np.random.uniform(0, 2, 1000)
ws = np.exp(np.random.normal(size=1000))
incomes = np.zeros(1000)
ms = np.zeros(1000)
e = 0.2

for i in range(1000):
    c, m = demandB(2, ws[i], e, Bs[i])
    incomes[i] = 2+ws[i]*m
    ms[i] = m

_, bins, _ = plt.hist(ms, 10, density=1, alpha=0.5)
mu, sigma = stats.norm.fit(ms)
best_fit_line = stats.norm.pdf(bins, mu, sigma)
plt.plot(bins, best_fit_line)
plt.xlim(0,10)
plt.show ()

# %% [markdown]
# ##### Problem 3d.
# Let us set up a model with 1000 consumers. Let B be uniformly distributed (on some suitable interval. Let the log wage w have a standard normal distribution that is independent of B. Plot the resulting income distribution.

# %%
def demandB(income,wage,e,B):
    
    def utility(l,c,e):
        
        denominator = (1+1/(-e))
        
        return c + (1/denominator) * np.power(l, denominator)

    def utilitybudget(l, mylist):
        
        I = mylist[0] 
        e = mylist[2] 
        w = mylist[1] 
        c = I + w*(1 - l)
        
        return utility(l, c, e)
    
    def demand(I,w,e):
        l = our_newton_maximizer(utilitybudget,0.1,[I,w,e])
        c = I + w*(1-l)
        
        return l, c

    #leisure, conumption = demand

    c, m = demand(income, wage, e)
    util = utility(c,m,e)-B
    util2 = utility(income, 0, e)
    
    if util2 > util:
        c = income
        m = 0
        
    return c,m

Bs = np.random.uniform(size=1000)*2
ws = np.log(np.random.normal(4,0.1,size=1000))

incomes =np.zeros(1000)
ms = np.zeros(1000)
e = 0.2

for i in range(1000):
    
    (c,m) = demandB(2,ws[i],e,Bs[i])
    incomes[i] = 2+ws[i]*m
    ms[i] = m

_, bins, _ = plt.hist(ms, 10, density=1, alpha=0.5)
mu, sigma = stats.norm.fit(ms)
best_fit_line = stats.norm.pdf(bins, mu, sigma)
plt.plot(bins, best_fit_line)

# %% [markdown]
# ##### Problem 3e.
# Increase wages by ten percent. Plot the distribution of individual income changes and changes in labor supply in response to the change. Can you quantify how much of the increase in labor supply that is given by extensive margin responses (people start working) and how much is from intensive margin responses (people who already work choose to work more).

# %% [markdown]
# ### Problem 4 - Taxation in the labour supply model.<a class="anchor" id="Problem4"></a>
# [[Back to TOC]](#Table-of-Contents)

# %% [markdown]
# ##### Problem 4a.
# We will now introduce taxes on labor income in the model above. Let the tax system be as follows: Incomes from 0 to 1 are taxed with a rate t1 and incomes beyond 1 are taxed with a rate t2. The budget is now $$ c = I + wm(1-t_1)$$ for $wm < 1$ and: $$ c = I + (1-t_1) + (1-t_2)\times(wm-1) $$ for $wm > 1$. Compute the consumer behavior and tax revenue.

# %%
def p54(wages, arglist):
    
    ''' 
    Parameters :
    wages = list of wages to loop in 
    I = income 
    e = substitution parameter (0,1)
    t1 = tax rate 1 
    t2 = tax rate 2 '''
    
    I = arglist[0] 
    e = arglist[1] 
    t1 = arglist[2] 
    t2 = arglist[3]
    
    for i in range(len(wages)): 
        
        w = wages[i]
        
        def utility(l,c,e):
            denominator = (1+1/(-e))
            return c + (1/denominator) * np.power(l, denominator)
            

        def utilitybudget(l, mylist):
            
            I = mylist[0] 
            e = mylist[2] 
            w = mylist[1]
            
            if w*(1-l) <= 1: 
                c = I + w*(1 - l)*(1-t1)
                
            else : 
                c = I + (1-t1) + (1-t2)*(w*(1-l) -1)
                
            return utility(l, c, e)

        def demand(I, w, e):
            l = our_newton_solver(utilitybudget, 0.1, [I,w,e])
            
            if (w*(1-l) <= 1).all: 
                c = I + w*(1 - l)*(1-t1)
                
            else : 
                c = I + (1-t1) + (1-t2)*(w*(1-l)-1)
                
            return l, c

        def indiffdist(c, mylist):
            
            l = mylist[0] 
            e = mylist[2]
            utilitylevel = mylist[1] 
            utilityachieved = utility(l, c, e)
            
            return utilityachieved - utilitylevel  

        def indiff(l, util, e):    
            return our_newton_solver(indiffdist, 1, [l,util,e])

        def indirectutility(I,w,e):
            l, c = demand(I, w, e) 
            return utility(l, c, e)

        #Initiliase some quantities of the two goods
        l = np.linspace(0.1, 10, 100) 
        c = np.zeros(np.size(l)) 

        # get indirect utility curve here
        utility_level = indirectutility(I, w, e)
        c = np.zeros(len(l)) 
        
        dems = np.zeros(len(l))

        for element in range(len(l)):
            c[element] = indiff(l[element], utility_level,e)

        if w*(1-l) < 1 :
            cons = lambda l,I,w,t1: I + w*(1-l)*(1-t1) 
            
        else:
            cons = lambda l,I,w,t1,t2: I + (1-t1) + (1-t2)*(w*(1-l) -1)

        plt.figure(figsize = (10,6))
        
        # plot and make nice
        plt.figure(figsize = (6,4)) 
        plt.plot(l, c, label = f'Indifference curve, w = {np.round(w,2)}')
        plt.plot(l,  cons(l,I,w), color = 'red', label = f'budget line, w = {np.round(w,2)}')

        # points
        dem = []
        dem= demand(I,w,e) 
        plt.scatter(dem[0],dem[1], label = "Optimum consumption and leisure", color ='black')
        plt.text(dem[0], dem[1], '({}, {})'.format(np.round(dem[0],2), np.round(dem[1],2)))
        plt.vlines(dem[0],0,dem[1],linestyles='dotted')
        plt.hlines(dem[1],0,dem[0],linestyles='dotted')

        plt.xlabel('Quantity of leisure, l') 
        plt.ylabel('Quantity of consumption, c')
        plt.legend(loc = 'lower left')
        plt.xlim(0,10) 
        plt.ylim(0,18)
        plt.title('Quasi-linear utility, Work Supply problem')

# %%
ws = np.linspace(0.1,6,100) 
#p54(ws,[1,0.2,0.1,0.2])

# %% [markdown]
# ##### Problem 4b.
# Play around with different tax systems. Look at how they affect behavior and what the tax revenues are.

# %% [markdown]
# ##### Problem 4c.
# Compute the welfare loss at the individual level of the tax system compared to no tax system (that is, how much would the individual be willing to pay to get rid of the tax).

# %% [markdown]
# ##### Problem 4e.
# Try to find three or four different tax systems that raise the same revenue and compare their welfare effects.
